# %% [markdown]
# # IS MS DHONI STILL GOOD TO PLAY CRICKET?

# %% [markdown]
# ## PARAMETERS:
#
# ### OVERALL STRIKERATE IN IPL
# ### OVERALL STRIKERATE AGAINST SPIN IN IPL- DONE
# ### OVERALL STRIKERATE AGAINST PACE IN IPL- DONE
# ### YEAR BY YEAR STRIKERATE IN IPL - DONE
# ### YEAR BY YEAR STRIKERATE AGAINST SPIN IN IPL
# ### YEAR BY YEAR STRIKERATE AGAINST PACE IN IPL
# ### YEAR BY YEAR STRIKERATE AT HOME VENUE IN IPL
# ### YEAR BY YEAR STRIKERATE AGAINST SPIN AT HOME VENUE IN IPL
# ### YEAR BY YEAR STRIKERATE AGAINST PACE AT HOME VENUE IN IPL

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

pd.set_option('display.max_rows',None)
pd.set_option('display.max_columns',None)
pd.set_option('display.expand_frame_repr',False)
pd.set_option('max_colwidth',None)

import warnings
warnings.simplefilter("ignore", UserWarning)

# %%
df = pd.read_csv("cleaned_ipl_dataset_2008_to_2022.csv")

# %% [markdown]
# # OVERALL STRIKERATE AGAINST SPIN IN IPL

# %%
# df["batting_team"].unique()

# %%
# df["striker"].unique()

# %%
# ex = df[df["striker"]=="MS Dhoni"]

# %%
# ex.shape

# %%
dflegal = df[df["legal_ball"]==1]

# %%
ms0 = dflegal[dflegal["striker"]=="MS Dhoni"]

# %%
msspin = ms0[ms0["bowling_style"]=="Spin"]

# %%
mspace = ms0[ms0["bowling_style"]=="Pace"]

# %%
mss1 = msspin.groupby("bowler")["runs_off_bat"].sum()
mss1 = pd.DataFrame(mss1).reset_index()

# %%
mss2 = msspin.groupby("bowler")["ball"].count()
mss2 = pd.DataFrame(mss2).reset_index()

# %%
mss3 = pd.merge(mss1,mss2,on="bowler",how="left").reset_index(drop=True)

# %%
ms_vs_spin = mss3[mss3["ball"]>=20].reset_index(drop=True)

# %%
ms_vs_spin["strike_rate"] = 100*(ms_vs_spin.runs_off_bat/ms_vs_spin.ball)

# %%
# ms

# %%
plt.figure(figsize=(16,8))
plt.rcParams['axes.facecolor'] = 'lightyellow'
plt.title("MS DHONI STRIKERATE vs SPIN in IPL(min 20 balls)",fontsize=20)
plt.xlabel("Strike Rate",fontsize=15)
plt.ylabel("Runs",fontsize=15)
plt.axvline(130,ls="--",color="blue")

for i in range(len(ms_vs_spin)):
    if ms_vs_spin["bowler"][i]=="KV Sharma":
        plt.text(ms_vs_spin["strike_rate"][i],ms_vs_spin["runs_off_bat"][i]+1,ms_vs_spin["bowler"][i])
    elif ms_vs_spin["bowler"][i]=="RD Chahar":
        plt.text(ms_vs_spin["strike_rate"][i]-1,ms_vs_spin["runs_off_bat"][i]+2,ms_vs_spin["bowler"][i])
    elif ms_vs_spin["bowler"][i]=="A Kumble":
        plt.text(ms_vs_spin["strike_rate"][i],ms_vs_spin["runs_off_bat"][i]-2,ms_vs_spin["bowler"][i])
    elif ms_vs_spin["bowler"][i]=="CH Gayle":
        plt.text(ms_vs_spin["strike_rate"][i]-2,ms_vs_spin["runs_off_bat"][i]-3,ms_vs_spin["bowler"][i])
    elif ms_vs_spin["bowler"][i]=="Iqbal Abdulla":
        plt.text(ms_vs_spin["strike_rate"][i]-11,ms_vs_spin["runs_off_bat"][i]-1,ms_vs_spin["bowler"][i])
    elif ms_vs_spin["bowler"][i]=="Harbhajan Singh":
        plt.text(ms_vs_spin["strike_rate"][i]-13,ms_vs_spin["runs_off_bat"][i]-1,ms_vs_spin["bowler"][i])
    else:
        plt.text(ms_vs_spin["strike_rate"][i]+1,ms_vs_spin["runs_off_bat"][i]-1,ms_vs_spin["bowler"][i])

plt.scatter(ms_vs_spin.strike_rate,ms_vs_spin.runs_off_bat, )
plt.savefig("MS DHONI SR vs SPIN in IPL")
plt.show()

# %% [markdown]
# # OVERALL STRIKERATE AGAINST PACE IN IPL

# %%
msp1 = mspace.groupby("bowler")["runs_off_bat"].sum()
msp1 = pd.DataFrame(msp1).reset_index()

# %%
msp2 = mspace.groupby("bowler")["ball"].count()
msp2 = pd.DataFrame(msp2).reset_index()

# %%
msp3 = pd.merge(msp1,msp2,on="bowler",how="left").reset_index(drop=True)

# %%
ms_vs_pace = msp3[msp3["ball"]>=20].reset_index(drop=True)

# %%
ms_vs_pace["strike_rate"] = 100*(ms_vs_pace.runs_off_bat/ms_vs_pace.ball)

# %%
plt.figure(figsize=(16,8))
plt.rcParams['axes.facecolor'] = 'lightyellow'
plt.title("MS DHONI STRIKERATE vs PACE in IPL(min 20 balls)",fontsize=20)
plt.xlabel("Strike Rate",fontsize=15)
plt.ylabel("Runs",fontsize=15)
plt.axvline(130,ls="--",color="blue")

for i in range(len(ms_vs_pace)):
    if ms_vs_pace["bowler"][i]=="NA Saini":
        plt.text(ms_vs_pace["strike_rate"][i]-1,ms_vs_pace["runs_off_bat"][i]+1,ms_vs_pace["bowler"][i])
    elif ms_vs_pace["bowler"][i]=="MP Stoinis":
        plt.text(ms_vs_pace["strike_rate"][i]+1,ms_vs_pace["runs_off_bat"][i]-2,ms_vs_pace["bowler"][i])
    elif ms_vs_pace["bowler"][i]=="R Bhatia":
        plt.text(ms_vs_pace["strike_rate"][i]+1,ms_vs_pace["runs_off_bat"][i]-2,ms_vs_pace["bowler"][i])
    elif ms_vs_pace["bowler"][i]=="SR Watson":
        plt.text(ms_vs_pace["strike_rate"][i]+1,ms_vs_pace["runs_off_bat"][i]-2,ms_vs_pace["bowler"][i])
    elif ms_vs_pace["bowler"][i]=="DS Kulkarni":
        plt.text(ms_vs_pace["strike_rate"][i],ms_vs_pace["runs_off_bat"][i]+1,ms_vs_pace["bowler"][i])
    elif ms_vs_pace["bowler"][i]=="AJ Tye":
        plt.text(ms_vs_pace["strike_rate"][i]+1,ms_vs_pace["runs_off_bat"][i]-2,ms_vs_pace["bowler"][i])
    elif ms_vs_pace["bowler"][i]=="P Kumar":
        plt.text(ms_vs_pace["strike_rate"][i]-9,ms_vs_pace["runs_off_bat"][i],ms_vs_pace["bowler"][i])
    elif ms_vs_pace["bowler"][i]=="JD Unadkat":
        plt.text(ms_vs_pace["strike_rate"][i]-5,ms_vs_pace["runs_off_bat"][i]-3,ms_vs_pace["bowler"][i])
    else:
        plt.text(ms_vs_pace["strike_rate"][i]+1,ms_vs_pace["runs_off_bat"][i]-1,ms_vs_pace["bowler"][i])

plt.scatter(ms_vs_pace.strike_rate,ms_vs_pace.runs_off_bat)
plt.savefig("MS DHONI SR vs PACE in IPL")
plt.show()

# %% [markdown]
# # OVERALL STRIKERATE IN IPL

# %%
ms0 = dflegal[dflegal["striker"]=="MS Dhoni"]

# %%
ms1 = ms0.groupby("bowler")["runs_off_bat"].sum()
ms1 = pd.DataFrame(ms1).reset_index()

# %%
ms2 = ms0.groupby("bowler")["ball"].count()
ms2 = pd.DataFrame(ms2).reset_index()

# %%
ms3 = pd.merge(ms1,ms2,on="bowler",how="left").reset_index(drop=True)

# %%
ms_ = ms3[ms3["ball"]>=20].reset_index(drop=True)

# %%
ms_["strike_rate"] = 100*(ms_.runs_off_bat/ms_.ball)

# %%
ms_ = ms_.sort_values("strike_rate")

# %%
ms_.shape
# Out:
# (65, 4)

# %%
plt.figure(figsize=(8,12))
plt.rcParams['axes.facecolor'] = 'lightyellow'
plt.title("MS DHONI STRIKERATE in IPL(min 20 balls)",fontsize=15)
plt.xlabel("Strike Rate",fontsize=12)
plt.ylabel("Bowler",fontsize=12)
plt.axvline(130,ls="--",color="orange")
plt.axhline(29.5,ls="--",color="orange")
plt.barh(ms_.bowler,ms_.strike_rate)
plt.savefig("MS DHONI SR in IPL")
plt.show()

# %% [markdown]
# # YEAR BY YEAR STRIKERATE IN IPL

# %%
df.season.unique()
# Out:
# array([2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018,
#        2019, 2020, 2021, 2022], dtype=int64)

# %%
msd1 = df[df["striker"]=="MS Dhoni"]

# %%
# msd1.head(1)

# %%
msd2 = msd1.groupby("season")["runs_off_bat"].sum()
msd2 = pd.DataFrame(msd2).reset_index()
msd3 = msd1.groupby("season")["ball"].count()
msd3 = pd.DataFrame(msd3).reset_index()

# %%
msd4 = pd.merge(msd2,msd3,on="season",how="left").reset_index(drop=True)

# %%
msd4["strike_rate"]=100*(msd4.runs_off_bat/msd4.ball)

# %%
msd4["strike_rate"]=msd4["strike_rate"].astype(int)

# %%
# msd4

# %%
plt.figure(figsize=(16,8))
plt.title("MS DHONI'S STRIKE RATE OVER THE YEARS IN IPL",fontsize=20)
plt.xlabel("Year",fontsize=15)
plt.ylabel("Strike Rate",fontsize=15)

for i in range(len(msd4)):
    if msd4["strike_rate"][i]==122:
        plt.text(msd4["season"][i],msd4["strike_rate"][i]-2,msd4["strike_rate"][i],color="green")
    elif msd4["strike_rate"][i]==133:
        plt.text(msd4["season"][i],msd4["strike_rate"][i]-2,msd4["strike_rate"][i],color="green")
    elif msd4["strike_rate"][i]==126:
        plt.text(msd4["season"][i],msd4["strike_rate"][i]-2,msd4["strike_rate"][i],color="green")
    elif msd4["strike_rate"][i]==120:
        plt.text(msd4["season"][i],msd4["strike_rate"][i]-2,msd4["strike_rate"][i],color="green")
    elif msd4["strike_rate"][i]==111:
        plt.text(msd4["season"][i],msd4["strike_rate"][i]-2,msd4["strike_rate"][i],color="green")
    elif msd4["strike_rate"][i]==102:
        plt.text(msd4["season"][i],msd4["strike_rate"][i]-2,msd4["strike_rate"][i],color="green")
    else:
        plt.text(msd4["season"][i],msd4["strike_rate"][i]+1,msd4["strike_rate"][i],color="green")

plt.plot(msd4.season,msd4.strike_rate,ls="-",marker=".",markersize=10)
plt.savefig("MS DHONI'S STRIKE RATE OVER THE YEARS IN IPL")
plt.show()

# %% [markdown]
# # YEAR BY YEAR STRIKERATE AGAINST SPIN IN IPL

# %%
msd2 = msspin.groupby("season")["runs_off_bat"].sum()
msd2 = pd.DataFrame(msd2).reset_index()
msd3 = msspin.groupby("season")["ball"].count()
msd3 = pd.DataFrame(msd3).reset_index()

# %%
msd4 = pd.merge(msd2,msd3,on="season",how="left").reset_index(drop=True)

# %%
msd4["strike_rate"]=100*(msd4.runs_off_bat/msd4.ball)

# %%
msd4["strike_rate"]=msd4["strike_rate"].astype(int)

# %%
plt.figure(figsize=(16,8))
plt.title("MS DHONI'S STRIKE RATE OVER THE YEARS AGAINST SPIN IN IPL",fontsize=20)
plt.xlabel("Year",fontsize=15)
plt.ylabel("Strike Rate",fontsize=15)

for i in range(len(msd4)):
    if msd4["strike_rate"][i]==93:
        plt.text(msd4["season"][i]+0.10,msd4["strike_rate"][i],msd4["strike_rate"][i],color="green")
    elif msd4["strike_rate"][i]==100:
        plt.text(msd4["season"][i],msd4["strike_rate"][i]-2,msd4["strike_rate"][i],color="green")
    elif msd4["strike_rate"][i]==84:
        plt.text(msd4["season"][i],msd4["strike_rate"][i]-2,msd4["strike_rate"][i],color="green")
    else:
        plt.text(msd4["season"][i],msd4["strike_rate"][i]+1,msd4["strike_rate"][i],color="green")

plt.plot(msd4.season,msd4.strike_rate,ls="-",marker=".",markersize=10)
plt.savefig("MS DHONI'S STRIKE RATE AGAINST SPIN OVER THE YEARS IN IPL")
plt.show()

# %% [markdown]
# # YEAR BY YEAR STRIKERATE AGAINST PACE IN IPL

# %%
msd2 = mspace.groupby("season")["runs_off_bat"].sum()
msd2 = pd.DataFrame(msd2).reset_index()
msd3 = mspace.groupby("season")["ball"].count()
msd3 = pd.DataFrame(msd3).reset_index()

# %%
msd4 = pd.merge(msd2,msd3,on="season",how="left").reset_index(drop=True)

# %%
msd4["strike_rate"]=100*(msd4.runs_off_bat/msd4.ball)

# %%
msd4["strike_rate"]=msd4["strike_rate"].astype(int)

# %%
plt.figure(figsize=(16,8))
plt.title("MS DHONI'S STRIKE RATE OVER THE YEARS AGAINST PACE IN IPL",fontsize=20)
plt.xlabel("Year",fontsize=15)
plt.ylabel("Strike Rate",fontsize=15)

for i in range(len(msd4)):
    if msd4["strike_rate"][i]==127:
        plt.text(msd4["season"][i],msd4["strike_rate"][i]-2,msd4["strike_rate"][i],color="green")
    elif msd4["strike_rate"][i]==154:
        plt.text(msd4["season"][i],msd4["strike_rate"][i]-2,msd4["strike_rate"][i],color="green")
    elif msd4["strike_rate"][i]==135:
        plt.text(msd4["season"][i],msd4["strike_rate"][i]-2,msd4["strike_rate"][i],color="green")
    elif msd4["strike_rate"][i]==118:
        plt.text(msd4["season"][i],msd4["strike_rate"][i]-2,msd4["strike_rate"][i],color="green")
    elif msd4["strike_rate"][i]==142:
        plt.text(msd4["season"][i],msd4["strike_rate"][i]-2,msd4["strike_rate"][i],color="green")
    elif msd4["strike_rate"][i]==129:
        plt.text(msd4["season"][i],msd4["strike_rate"][i]-2,msd4["strike_rate"][i],color="green")
    else:
        plt.text(msd4["season"][i],msd4["strike_rate"][i]+1,msd4["strike_rate"][i],color="green")

plt.plot(msd4.season,msd4.strike_rate,ls="-",marker=".",markersize=10)
plt.savefig("MS DHONI'S STRIKE RATE AGAINST PACE OVER THE YEARS IN IPL")
plt.show()

# %% [markdown]
# # YEAR BY YEAR STRIKERATE AT HOME VENUE IN IPL

# %%
df1 = dflegal[dflegal["venue"]=="MA Chidambaram Stadium"]

# %%
df2 = dflegal[dflegal["venue"]=="MA Chidambaram Stadium, Chepauk"]

# %%
df3 = pd.concat([df1,df2])

# %%
df3.tail()
# Out:
#         match_id  season  start_date                   venue  innings  ball    batting_team         bowling_team  striker non_striker    bowler  runs_off_bat  extras  wides  noballs  byes  legbyes  penalty wicket_type player_dismissed  other_wicket_type  other_player_dismissed          bowl_style bowling_style          bat_style batting_style  wides_cnt_balls  noballs_cnt_balls  noballs_cnt_balls_bowler  byes_cnt_balls  legbyes_cnt_balls  legal_ball  legal_ball_bowler  over_no  ball_no phase
# 198180   1254077    2021  2021-04-25  MA Chidambaram Stadium        1   0.6  Delhi Capitals  Sunrisers Hyderabad  PP Shaw    S Dhawan  KK Ahmed             0       0    NaN      NaN   NaN      NaN      NaN         NaN              NaN                NaN                     NaN   Right-arm medium           Pace   Left Handed Bat            LHB                1                  1                         1               1                  1           1                  1        0        6    PP
# ...

# %%
df4 = df3[df3["striker"]=="MS Dhoni"]

# %%
msd2 = df4.groupby("season")["runs_off_bat"].sum()
msd2 = pd.DataFrame(msd2).reset_index()
msd3 = df4.groupby("season")["ball"].count()
msd3 = pd.DataFrame(msd3).reset_index()

# %%
msd4 = pd.merge(msd2,msd3,on="season",how="left").reset_index(drop=True)

# %%
msd4["strike_rate"]=100*(msd4.runs_off_bat/msd4.ball)

# %%
msd4["strike_rate"]=msd4["strike_rate"].astype(int)

# %%
msd4
# Out:
#    season  runs_off_bat  ball  strike_rate
# 0    2008           204   160          127
# 1    2010            87    69          126
# 2    2011           192   130          147
# 3    2012           194   135          143
# 4    2013           260   164          158
# 5    2015           208   146          142
# 6    2018            25    28           89
# 7    2019           193   120          160

# %%
plt.figure(figsize=(16,8))
plt.title("MS DHONI'S STRIKE RATE OVER THE YEARS AT HOME VENUE IN IPL",fontsize=20)
plt.xlabel("Year",fontsize=15)
plt.ylabel("Strike Rate",fontsize=15)

for i in range(len(msd4)):
    if msd4["strike_rate"][i]==89:
        plt.text(msd4["season"][i],msd4["strike_rate"][i]-2,msd4["strike_rate"][i],color="green")
    elif msd4["strike_rate"][i]==143:
        plt.text(msd4["season"][i],msd4["strike_rate"][i]-2,msd4["strike_rate"][i],color="green")
    elif msd4["strike_rate"][i]==126:
        plt.text(msd4["season"][i],msd4["strike_rate"][i]-2,msd4["strike_rate"][i],color="green")
    else:
        plt.text(msd4["season"][i],msd4["strike_rate"][i]+1,msd4["strike_rate"][i],color="green")

plt.plot(msd4.season,msd4.strike_rate,ls="-",marker=".",markersize=10)
plt.savefig("MS DHONI'S STRIKE RATE OVER THE YEARS AT HOME VENUE IN IPL")
plt.show()

# %% [markdown]
# # YEAR BY YEAR STRIKERATE AGAINST SPIN AT HOME VENUE IN IPL

# %%
df5 = df4[df4["bowling_style"]=="Spin"]

# %%
msd2 = df5.groupby("season")["runs_off_bat"].sum()
msd2 = pd.DataFrame(msd2).reset_index()
msd3 = df5.groupby("season")["ball"].count()
msd3 = pd.DataFrame(msd3).reset_index()

# %%
msd4 = pd.merge(msd2,msd3,on="season",how="left").reset_index(drop=True)

# %%
msd4["strike_rate"]=100*(msd4.runs_off_bat/msd4.ball)

# %%
msd4["strike_rate"]=msd4["strike_rate"].astype(int)

# %%
plt.figure(figsize=(16,8))
plt.title("MS DHONI'S STRIKE RATE OVER THE YEARS AGAINST SPIN AT HOME VENUE IN IPL",fontsize=20)
plt.xlabel("Year",fontsize=15)
plt.ylabel("Strike Rate",fontsize=15)

for i in range(len(msd4)):
    if msd4["strike_rate"][i]==109:
        plt.text(msd4["season"][i],msd4["strike_rate"][i]-2,msd4["strike_rate"][i],color="green")
    elif msd4["strike_rate"][i]==133:
        plt.text(msd4["season"][i],msd4["strike_rate"][i]-2,msd4["strike_rate"][i],color="green")
    elif msd4["strike_rate"][i]==88:
        plt.text(msd4["season"][i]+0.07,msd4["strike_rate"][i]+1,msd4["strike_rate"][i],color="green")
    else:
        plt.text(msd4["season"][i],msd4["strike_rate"][i]+1,msd4["strike_rate"][i],color="green")

plt.plot(msd4.season,msd4.strike_rate,ls="-",marker=".",markersize=10)
plt.savefig("MS DHONI'S STRIKE RATE AGAINST PACE OVER THE YEARS AT HOME VENUE IN IPL")
plt.show()

# %% [markdown]
# # YEAR BY YEAR STRIKERATE AGAINST PACE AT HOME VENUE IN IPL

# %%
df5 = df4[df4["bowling_style"]=="Pace"]

# %%
msd2 = df5.groupby("season")["runs_off_bat"].sum()
msd2 = pd.DataFrame(msd2).reset_index()
msd3 = df5.groupby("season")["ball"].count()
msd3 = pd.DataFrame(msd3).reset_index()

# %%
msd4 = pd.merge(msd2,msd3,on="season",how="left").reset_index(drop=True)

# %%
msd4["strike_rate"]=100*(msd4.runs_off_bat/msd4.ball)

# %%
msd4["strike_rate"]=msd4["strike_rate"].astype(int)

# %%
plt.figure(figsize=(16,8))
plt.title("MS DHONI'S STRIKE RATE OVER THE YEARS AGAINST PACE AT HOME VENUE IN IPL",fontsize=20)
plt.xlabel("Year",fontsize=15)
plt.ylabel("Strike Rate",fontsize=15)

for i in range(len(msd4)):
    if msd4["strike_rate"][i]==102:
        plt.text(msd4["season"][i]+0.05,msd4["strike_rate"][i]-2,msd4["strike_rate"][i],color="green")
    elif msd4["strike_rate"][i]==150:
        plt.text(msd4["season"][i]+0.05,msd4["strike_rate"][i]-2,msd4["strike_rate"][i],color="green")
    elif msd4["strike_rate"][i]==100:
        plt.text(msd4["season"][i]+0.05,msd4["strike_rate"][i]-2,msd4["strike_rate"][i],color="green")
    else:
        plt.text(msd4["season"][i],msd4["strike_rate"][i]+1,msd4["strike_rate"][i],color="green")

plt.plot(msd4.season,msd4.strike_rate,ls="-",marker=".",markersize=10)
plt.savefig("MS DHONI'S STRIKE RATE AGAINT PACE OVER THE YEARS AT HOME VENUE IN IPL")
plt.show()
